# %%
print('hello')
# Out:
# hello

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import (
    Distance,
    VectorParams,
    PayloadSchemaType,
    PointStruct,
)
import pandas as pd
import openai
import os

api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    api_key = input("Please enter your OpenAI API key: ").strip()
    os.environ["OPENAI_API_KEY"] = api_key
    if not api_key:
        raise ValueError("API key is required.")

# %%
df_items = pd.read_json("../data/meta_Electronics_2022_2023_with_category_ratings_100_sample_1000.jsonl", lines=True)

# %%
df_items.head(2)
# Out:
#              main_category                                              title  \
# 0  Industrial & Scientific  RAVODOI USB C Cable, [2Pack/3.3ft+6.6ft] USB T...
# 1          All Electronics  SNESH-2 Pack USB-C Female to USB Male Adapter,...
#
#    average_rating  rating_number  \
# 0             4.4            119
# 1             4.5            352
#
#                                             features description  price  \
# 0  [【Fast Charging Cord】These USB C cables provid...          []    NaN
# 1  [🔹(Light & compact) Easy to carry and light we...          []   4.99
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos    store  \
# 0  [{'title': 'Type-C Charger Cable ', 'url': 'ht...  RAVODOI
# 1  [{'title': 'USB Male & Female Adapter', 'url':...    SNESH
#
#                                           categories  \
# 0  [Electronics, Computers & Accessories, Compute...
# 1  [Electronics, Computers & Accessories, Compute...
#
#                                              details parent_asin  \
# 0  {'Brand': 'RAVODOI', 'Connector Type': 'USB Ty...  B09R4Y2HKY
# 1  {'Package Dimensions': '3.54 x 2.4 x 0.35 inch...  B09JV5FM2S
#
#    bought_together  subtitle  author
# 0              NaN       NaN     NaN
# 1              NaN       NaN     NaN

# %%
def preprocess_data(row):
    return f"{row['title']} {' '.join(row['features'])}"

# %%
df_items.head(2)
# Out:
#              main_category                                              title  \
# 0  Industrial & Scientific  RAVODOI USB C Cable, [2Pack/3.3ft+6.6ft] USB T...
# 1          All Electronics  SNESH-2 Pack USB-C Female to USB Male Adapter,...
#
#    average_rating  rating_number  \
# 0             4.4            119
# 1             4.5            352
#
#                                             features description  price  \
# 0  [【Fast Charging Cord】These USB C cables provid...          []    NaN
# 1  [🔹(Light & compact) Easy to carry and light we...          []   4.99
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos    store  \
# 0  [{'title': 'Type-C Charger Cable ', 'url': 'ht...  RAVODOI
# 1  [{'title': 'USB Male & Female Adapter', 'url':...    SNESH
#
#                                           categories  \
# 0  [Electronics, Computers & Accessories, Compute...
# 1  [Electronics, Computers & Accessories, Compute...
#
#                                              details parent_asin  \
# 0  {'Brand': 'RAVODOI', 'Connector Type': 'USB Ty...  B09R4Y2HKY
# 1  {'Package Dimensions': '3.54 x 2.4 x 0.35 inch...  B09JV5FM2S
#
#    bought_together  subtitle  author
# 0              NaN       NaN     NaN
# 1              NaN       NaN     NaN

# %%
def extract_first_large_image(row):
    return row['images'][0].get('large', '')

# %%
df_items["preprocessed_data"] = df_items.apply(preprocess_data, axis=1)
df_items["first_large_image"] = df_items.apply(extract_first_large_image, axis=1)

# %%
df_items.head(2)
# Out:
#              main_category                                              title  \
# 0  Industrial & Scientific  RAVODOI USB C Cable, [2Pack/3.3ft+6.6ft] USB T...
# 1          All Electronics  SNESH-2 Pack USB-C Female to USB Male Adapter,...
#
#    average_rating  rating_number  \
# 0             4.4            119
# 1             4.5            352
#
#                                             features description  price  \
# 0  [【Fast Charging Cord】These USB C cables provid...          []    NaN
# 1  [🔹(Light & compact) Easy to carry and light we...          []   4.99
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos    store  \
# 0  [{'title': 'Type-C Charger Cable ', 'url': 'ht...  RAVODOI
# 1  [{'title': 'USB Male & Female Adapter', 'url':...    SNESH
#
#                                           categories  \
# 0  [Electronics, Computers & Accessories, Compute...
# 1  [Electronics, Computers & Accessories, Compute...
#
#                                              details parent_asin  \
# 0  {'Brand': 'RAVODOI', 'Connector Type': 'USB Ty...  B09R4Y2HKY
# 1  {'Package Dimensions': '3.54 x 2.4 x 0.35 inch...  B09JV5FM2S
#
#    bought_together  subtitle  author  \
# 0              NaN       NaN     NaN
# 1              NaN       NaN     NaN
#
#                                    preprocessed_data  \
# 0  RAVODOI USB C Cable, [2Pack/3.3ft+6.6ft] USB T...
# 1  SNESH-2 Pack USB-C Female to USB Male Adapter,...
#
#                                    first_large_image
# 0  https://m.media-amazon.com/images/I/51G07yWoOB...
# 1  https://m.media-amazon.com/images/I/41bOA5-ogW...

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

# %%
qdrant_client.create_collection(
    collection_name="Amazon-items-collection-01-hybrid",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE)
)
# Out:
# True

# %%
qdrant_client.create_payload_index(
    collection_name="Amazon-items-collection-01-hybrid",
    field_name="text",
    field_schema=PayloadSchemaType.TEXT
)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
df_sample = df_items.sample(50, random_state=25)

# %%
def get_embeddings(text, model="text-embedding-3-small"):
    
    response = openai.embeddings.create(
        input=[text],
        model=model
    )
    return response.data[0].embedding

# %%
data_to_embed = df_sample[["preprocessed_data", "first_large_image", "rating_number", "price", "average_rating"]].to_dict(orient="records")

# %%
data_to_embed
# Out:
# [{'preprocessed_data': 'Bluetooth Car Adapter, LDNIO Bluetooth FM Transmitter for Car, 43W PD&QC 3.0 Three USB Port Car Bluetooth Adapter with LED Display, Hands-Free Calling, and AUX Input for All Smartphones Audio Player Fast Charging Type C Multi Ports: USB Type C Durable Fast Connect & Clear Bluetooth Sound 3 in 1 Value',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41gqwN41WpL._AC_.jpg',
#   'rating_number': 110,
#   'price': 21.0,
#   'average_rating': 3.8},
#  {'preprocessed_data': 'Bluetooth Multi-Device Keyboard, Dual Channel Universal Rechargeable Wireless Keyboard with Integrated Stand for iPad Smartphone Tablet MacBook iOS Windows Android Devices - Pink 【Easy-Switch to 2 Devices】 Simply press the FN+BT1/BT2 to switch typing between 2 connected Bluetooth devices, work with your smartphone and tablet on the slot stablely. 【Type Anywhere in Comfort】0.46in thick and 11.34in long, the compact Bluetooth keyboard is small enough to tuck into your briefcase and light enough to hold in hand. Minimalist layout lets you multitask at home or on the go. 【Precise Light-Touch Typing】Scissor-Switch circle-shape keycaps and silicone non-slip pad backside, providing you with very comfortable and pleasing typing experience, also improving your work efficiency. 【Rechargeable Battery】The bluetooth rechargeable keyboard built-in 180mAh Li-ion Battery, 2 hours full charge, above 40 hours uninterrupted work. It will automatically enter sleep mode to save power, you can press any key to wake it up. 【Wide Compatibility】 For Windows, Mac or Chrome computers, Android or iOS mobile devices. Works on iPad Air, iPad 4 / 3 / 2, iPad Mini 4, iPhone, Galaxy Tab, Macbook, Surface pro & More bluetooth enable devices.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41U69pTP3jL._AC_.jpg',
#   'rating_number': 199,
#   'price': 26.99,
#   'average_rating': 4.6},
#  {'preprocessed_data': 'Active Noise Cancelling Wireless Earbuds, Bluetooth in-Ear Headphones Built-in 4 Mic ENC Call, Deep Bass Ear Buds,IPX6 Waterproof Stereo Earphones for iPhone,Samsung,Laptop (Blue) ♪【ANC Noise Cancelling&Game Mode】: These premium noise-canceling earbuds adopts professional audio active noise canceling technology, and the binaural microphone blocks environmental noise and enhances the voice experience. M48 wireless earbuds are built to provide the exceptional mobile gaming audio experience with an ultra-low 45ms latency.Taps 5 times to enter game mode,through quick sound effect and ideal gaming audio you never miss any game sound effects. ♪【HiFi Stereo Sound & Superior Clear Call 】: Heaphones equipped with a high-sensitivity diaphragm and dual 13mm drivers to restore audio authenticity and voice dynamics, crystal clarity and deep resonance bass characteristics enable you to enjoy immersive sound quality. Call noise canceling brings you crystal clear calls, even in a noisy environment,true wireless in-ear earbuds can achieve a perfect call experience and stereo sound. ♪【LED Light Display & USB-C Fast Charging】: Dual digital LED power display outside of the case is to show the power level for the charging case and to remind you to charge in time by USB-C charge quickly. Put wireless earphones back in the charging case, and the display will flash that meaning earbuds are being charged. 350mAH battery capacity charging case can provide 4 times full charging for two ear buds, each earphone can last for 4H, you can use it for a day without worry. ♪【Upgrade Bluetooth 5.3 & Auto Pairing & Reminder】: Adopting the latest Bluetooth technology 5.3, True wireless earbuds Bluetooth 5.3 have a faster transmission rate, lower latency, providing a fast and stable connection and signal transmission (10 meters barrier-free). Due to the replacement of old and new packaging, you may receive the package of Bluetooth 5.1, but the product is the latest version of Bluetooth 5.3, thanks for your understand. ♪【Touch Control & Transparent Mode】: Easy touch control brings you a convenient operation experience when answering calls, skipping songs, and selecting different listening modes by wireless earbuds bluetooth. With the Transprency mode, you can hear what you want to hear, so you can listen and interact with the world around you. You can clearly hear an announcement of the airline or subway, as well as the sound around you, without taking off the headphones.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41gDQBYBnJL._AC_.jpg',
#   'rating_number': 147,
#   'price': nan,
#   'average_rating': 3.9},
#  {'preprocessed_data': 'Noonkey 2K/3MP Light Bulb Security Camera 2 Pieces Alexa Light Bulb E27 Home WiFi Security Cameras with Automatic Human Tracking,Motion Zones Detection Alarm,Color Night Vision,Wireless 360° Pan/Tilt 𝟑𝐌𝐏: Our security camera indoor wireless 3 million pixels, compared to 1080P, 2 million pixels, the picture quality is clearer.which are 40% better than other 1080P pixel security camera images. 𝐖𝐢𝐫𝐞𝐥𝐞𝐬𝐬 𝐚𝐧𝐝 𝐄𝐚𝐬𝐲 𝐭𝐨 𝐈𝐧𝐬𝐭𝐚𝐥𝐥:You can directly use a common E27 bulb base (110V~240V) to install cameras for home security , no need to fix it with nails,security cameras wireless, more flexible and simple , can install anywhere you want . 𝐀𝐈 𝐈𝐧𝐭𝐞𝐥𝐥𝐢𝐠𝐞𝐧𝐜𝐞:The chips of our motion bulb camera has AI functions, humanoid framing functions, human tracking functions, motion detection functions, and accurate push messages. 𝟑 𝐍𝐢𝐠𝐡𝐭 𝐕𝐢𝐬𝐢𝐨𝐧 𝐌𝐨𝐝𝐞𝐬:Wireless security camera has black and white mode,color mode,smart mode.Color Mode: the spotlight will be on all night, you can get colorpicture;Infrared Mode: black and white image; Auto Mode:When the outdoor cameras for home security detects motion, the spotlights will light up and the image will be in full color. If the outdoor security camera does not detect motions, the image is in black and white. 𝐐𝐮𝐢𝐜𝐤 𝐂𝐨𝐧𝐧𝐞𝐜𝐭𝐢𝐨𝐧:No need to scan the QR code, connect via Bluetooth.Even if we buy wireless WiFi light bulb camera for the first time, can connect easily, and we are ready to install the video to help you,don’t worry.Even if we buy wireless monitoring for the first time, we can see the operation, and we are ready to install the video.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41WoA7kyfsL._AC_.jpg',
#   'rating_number': 187,
#   'price': 49.99,
#   'average_rating': 3.9},
#  {'preprocessed_data': 'tifanso Cable Clips Cord Holder - 6pcs Cable Wire Organizer, Adhesive Cord Holder for Desk, Cord Clips, Cord Cable Clip, Cable Holder Wire Holders for Cords, Nightstand, Home and Office (Colorful) Practical Cable Clips - There is a strong adhesive self-adhesive liner at the back of cord holder, which is easy to peel and paste. Cord holder for desk is easy to disassemble and will not leave glue that is difficult to clean. No need to rearrange the wires and keep them neat 24 hours. Goodbye Tangled Wires - Cable holder is applicable to wires with a diameter of 0.39 inch, such as network cable, TV-coax cable, USB cords, cell phone charger cable, lightning cable, various electrical appliances wires. Tidy up the wires to give you a clean and tidy environment with this cord clips. Installed in Various Places - Cable clips can be pasted on any dry and clean place, like table or wall, metal, glass or wood surface, wire holders for cords can be easily competent. You can use phone cord holder to arrange your wires neatly in your home, office or car cab. Please note that cord holders for cables does not apply to rough and uneven surfaces. Multipurpose Cable Organizer - In addition to arranging wires, cord clips management can be used as a pen holder, floss and toothbrush holder. Cord holder for desk will also help you decorate lights for Halloween and Christmas at home, also a perfect cord holder for nightstand. You can find many more uses for cable holders for cords yourself at home or office. Package Includes - 6pcs wire organizer clips, the inner diameter of cable clips: 0.39 inch, 0.99 cm. Please wipe the surface clean before use cord clips for desk. Peel off the sticker on the back of the adhesive cable management clips, then stick the desk cord holder on and press firmly for 15 seconds. Please use it after 24 hours for the charger cable holder to have sufficient adhesion.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/31JlN06qaKL._AC_.jpg',
#   'rating_number': 179,
#   'price': 4.49,
#   'average_rating': 4.6},
#  {'preprocessed_data': 'Glorious Model D Wireless Gaming Mouse - RGB Mouse Wireless - 69 g Superlight Mouse - Ergonomic Computer Mouse - Honeycomb Mouse (Matte Black) Fast Connection: The model d bluetooth mouse has the lowest latency in its class, making it a top performing wireless mouse. Gives you the performance of a wired mouse without the cord. Wired & Wireless Modes: Model D Wireless comes with a flexible USB-C Ascended charging cable for nonstop performance when you need it most. Long Lasting: Model D Wireless has the highest battery life of any mouse in its class. Up to 71 hours of playtime so you can go all night. Complete with fast charging to get you back in the game. Honeycomb Mouse Design: Our honeycomb design helps create the ultimate lightweight mouse. This honeycomb gaming mouse combines performance and durability into one for the perfect gamer mouse. Superlight : Model D wireless is one of the lightest wireless mice of its kind. Weighing in at just 69 Grams, with top tier features such as customizable RGB lighting.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/419Jf-ix2zL._AC_.jpg',
#   'rating_number': 559,
#   'price': 56.52,
#   'average_rating': 4.5},
#  {'preprocessed_data': 'LinkMore NR34 128GB USB 3.1 Flash Drive, Read Speed up to 120MB/s, Write Speed up to 60MB/s, Thumb Drive Interface : USB 3.1 Storage Capacities : 128GB Max Sequential Read : 120MB/s Max Sequential Write : 60MB/s Power Consumption(Avg.) : 4.5~5.5V System Compatibility : Windows 7/8.1/10/11 Linux kernel 2.4 and later version Mac OS X 10.8 and later versio Warranty : 5 years from the date of purchase',
#   'first_large_image': 'https://m.media-amazon.com/images/I/21OhSadNDGL._AC_.jpg',
#   'rating_number': 319,
#   'price': 11.99,
#   'average_rating': 4.5},
#  {'preprocessed_data': 'LDYAN Owl Holder Stand, Owl Statue Smart Speaker Holder Stand for Echo Dot 4th/3rd/2nd and 1st Generation, Google Home Mini/Google Nest Mini (2nd Gen)，Leopard Print Design Owl Shape Home Decor 【Echo Dot Holder】The smart speaker holder perfectly matches the 4th echo dot, also applies to 3rd and 2nd and 1st Generation. One for all, no need to match different stands for different sizes of echo dot. 【Better Sound Experience】Porous design on the back, the Echo Dot holder almost exposes the speakers to improve the sound quality without any block,making it louder and clearer.A gap between the holder and the echo dot, releasing the sound quality. 【Safety and Environmental Protection】The speaker stand protects your echo dot speaker from knocking over, avoids dropping and water sputtering. The bottom silicone pad keeps the Echo Dot firmly in place on the table, protects table surface from scratching, and avoids slipping in smooth surface. The owl statue crafted speaker stand is made from the ABS, which is very environmentally protective and no pollution. 【Multifunctional】This owl echo dot holder is crafted by skillful workers according to traditional statue craft, the echo dot case style is cute and fashionable. Not only can be used as a speaker stand, can also be placed at home as a fine craft. 【Lightweight and Convenient】No complicated installation process.The owl echo dot stand is very lightweight,so it is very convenient for your use at any time and anywhere. Save your space. No matter you place it on kitchen,bedside cabinet,living room or bathroom,it will be a beautiful view in your room.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41aCOYCTWZL._AC_.jpg',
#   'rating_number': 291,
#   'price': 23.99,
#   'average_rating': 4.8},
#  {'preprocessed_data': "YAXIN 3 Pack Slim Sport Bands Compatible with Fitbit Versa/Fitbit Versa 2/Fitbit Versa Lite Band for Women,Soft Silicone Lace Replacement Wristbands for Fitbit Versa Smart Watch,Black/Pink Sand/Gray 【Compatible Models】YAXIN Thin Lace silicone Replacement Strap Specially Designed for Fitbit Versa 2/Versa/Versa Lite.Note: Those Bands don't fit Fitbit Versa 3/Versa Sense.One Size: Fits for 5.6 inch -7.1 inch(140mm-180mm) wrist. (Package: 3* Sport Lace Silicone bands, 3*stainless steel pins) Please Choose your favorite Fitbit Versa smart watch accessories 【Newest Design!Patents Product】YAXIN band Compatiable for Fitbit Versa/Fitbit Versa 2/Fitbit Versa Lite with fashion narrow thin slim design, elegant flower lace hollowed-out pattern makes your smart watch more thinner, lighter and less bulky.These Fitbit Versa watch bands adopted classic metal clasp, it is more security and stable. Perfectly fits for women ladies girls daily wear. 【Soft Silicone Material】Our Fitbit Versa watch bands for women are made of premium lace silicone, breathable and comfortable for your wrist. The Fitbit Versa watch band is soft, odorless, durable, waterproof, dirt-proof, lightweight and skin-friendly. 【Secure and Easy to Install】YAXIN for Fitbit Versa bands come with connectors that are easy to remove and install, which click precisely and securely onto the your Fitbit Versa Smart Watch interface.No longer worry about losing your watch. Adjustable size for 5.6 inch -7.1 inch(140mm-180mm) wrist. 【Best Service】We provide you with the best quality and service. If you have any questions about our watch band, please contact us, we will help you solve your problem within 24 hours.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/41vehhtSZtL._AC_.jpg',
#   'rating_number': 2268,
#   'price': 13.99,
#   'average_rating': 4.7},
#  {'preprocessed_data': "maio Bluetooth Speaker - Portable Wireless Speaker with 30W Stereo Deep Bass, IPX67 Waterproof, TWS, 18H Playtime, Dual Pairing - Compact Speaker for Home, Outdoor Camping, Party - Black 🎶【Enhanced Sound Portable Bluetooth Speaker】Immerse yourself in the world of high-quality sound with this compact wireless Bluetooth speaker. Perfect for both indoor and outdoor use, these portable speakers Bluetooth wireless deliver a powerful and dynamic performance, making them the ideal companion for music enthusiasts, parties, and outdoor adventures. 🎶【Dual Pairing and True Wireless Stereo】Elevate your audio experience by connecting these two same model Bluetooth speakers for a captivating surround sound. Alternatively, use a single speaker and still enjoy excellent audio performance. With Bluetooth 5.0 technology, experience seamless pairing and stable connections with smartphones, tablets, and computers. 🎶【IP67 Waterproof and Durable Design】Engineered with an IP67 waterproof rating, this waterproof Bluetooth speaker is designed to resist water splashes, rain, and submersion in up to 1m of water for 30 minutes. Its silicone buttons and rugged construction ensure durability and protection against accidental drops, making it your perfect companion for camping trips and pool parties. 🔋 【Long Battery Life & Dynamic Light Show】Enjoy up to 8 hours of playtime at 60% volume, thanks to the powerful 4000mAh battery. But that's not all - this bass speakers bluetooth wireless comes alive with dynamic, multicolor lights that sync to the music's beat, creating an immersive light show. Make your gatherings unforgettable with these stunning lights. Remember, actual playtime may vary due to volume, lighting, audio content, and usage. 🎶【Multiple Functions and Lightweight】This bluetooth speakers portable wireless support Bluetooth playback, TWS, and Aux-in, offering versatile entertainment options. Weighing only 510g, these portable outdoor speakers are highly portable and suitable for outdoor adventures, camping, parties, and more. Elevate your music experience with immersive LED light synchronization.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/51CJLYNWtML._AC_.jpg',
#   'rating_number': 216,
#   'price': 39.99,
#   'average_rating': 4.7},
#  {'preprocessed_data': "EVGA GeForce RTX 3080 FTW3 Ultra Gaming, 12G-P5-4877-KL, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR Digital Max Resolution:7680 x 4320 Real Boost Clock: 1800 MHz; Memory Detail: 12288 MB GDDR6X. Real-Time RAY TRACING in games for cutting-edge, hyper-realistic graphics. Triple Fans plus 9 iCX3 thermal sensors offer higher performance cooling and much quieter acoustic noise. All-Metal Backplate and Adjustable ARGB 3 Year Warranty and EVGA's Top Notch Technical Support.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/416Eco7X74L._AC_.jpg',
#   'rating_number': 461,
#   'price': 1465.0,
#   'average_rating': 4.7},
#  {'preprocessed_data': "Hearprotek Sleep Earbuds Lightweight Soft Noise Reduction Earbuds Wired with Mic and Volume Control, 3.5mm Tangle Free Sleep Headphones for Side Sleepers, Snoring, Air Travel, Meditation, Relaxation [Super Comfy &Light Weight] Earphones are made from flexible silicone, which enables them to easily conform to your ear canal painless without bothering your ear. Super lightweight, only weighs 0.36oz (10.2g/pair), which are almost hardly feel them when sleeping，the best companion for side sleepers. [Double Layers Design & Noise Reduction] Sleeping earphones are adapted with double layers design to provide better noise reduction. You don't need have to sleep on your back, side sleeper also could get a good night. Earphone keeps the traffic noise, neighbour noise, the ticking of clock, office noise out of your ear, and the music will soothe the stress of all day. [Durable & Tangle Free] The earbuds are built in bulletproof tough wire which are durable and flexible. You don't have to worry about damage from your sleeping posture or entanglement. The 125CM extra long thin wire won’t restrict your movement as well. [Wide Compatibility] With 3.5mm jack plug, fits any standard audio device, you can easily fall asleep to your favorite music, audiobooks, podcasts and soothing sounds. [Multiple Button Control] Features with 3-button control, you can switch music and answer/reject phone call on your fingertip easily. You can soothe your tired mind and enjoy a restful sleep by listening to white noise or calming music.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/31AeW1yns+L._AC_.jpg',
#   'rating_number': 2808,
#   'price': 10.99,
#   'average_rating': 4.3},
#  {'preprocessed_data': "Double Din Car Stereo - Corehan 10 inch Touchscreen Car Radio Bluetooth Multimedia Player with Backup Camera Compatible with Wireless Carplay, Wireless Android Auto, Mirror Link ✔Compatible with Wireless CarPlay and Wireless Android Auto. Turn Your Dashboard into a Mobile Command Center - Your dashboard just got smarter. 1 second super fast boot. Compatible with wireless Apple CarPlay and Android Auto, no cord, no connection, this touch screen car stereo lets you conveniently access apps from iPhone and Android phone. ✔Mirror Your Phone to a Bigger Screen - Enjoy a 10 inches high resolution bigger screen. Mirror-link your phone display on the 10 inch touch screen of the car stereo with Bluetooth for an enjoyable riding experience. ✔Multimedia Player - Equipped with USB to offer multiple options for music and movie enjoyment in the vehicle. The Bluetooth connectivity allows for hands-free calling, and wireless music sharing, wireless Carplay, wireless Android auto via your smartphone. It delivers an amazing experience for entertainment and beyond during your drive. ✔Your Car's Best Assistant - Come with a complimentary water-proof, wide-angle reverse camera. For a ride that's both safe and fun, this 10-inch double DIN car stereo comes with radio reception, steering wheel control access, and backup camera support. ✔New Mounting Install Design - Perfect fit for Metra & Scosche's aftermarket dash kit. The newly designed mounting bracket can be easily and quickly installed on all aftermarket double-spindle dash kits. We also provide 7*24 hours of after-sales technical support to help you solve installation and operation problems.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/51fErD18+0L._AC_.jpg',
#   'rating_number': 361,
#   'price': 141.96,
#   'average_rating': 4.4},
#  {'preprocessed_data': 'Car Apple Carplay Cable, USB A to Lightning Cable for iPhone 14, 14 pro max,13,Plus,SE 2nd/12/11/Xs/XR, iPad 4/5/ 6/7/ 8, Mini 2/3/4/5, Air 2/3 Charger Cord, Car Charging Cable This cable connects your iPhone 14/13/SE 2nd/12/11/Xs/XR/8/7/6 All series, USB A to Lightning Cable. With Lightning Connector to your USB port for syncing and charging. 1 meter in length (3.3ft). Worry-free 1-year warranty, lifetime technical support. *Note: If you experience issues with CarPlay function, please try to reverse the lightning plug to try again. Feel free to contact us if any further problem. We will always be here to help.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/31wpn1SmhdL.jpg',
#   'rating_number': 209,
#   'price': 9.99,
#   'average_rating': 4.4},
#  {'preprocessed_data': 'NEEWER ND Filter Set Compatible with DJI Mini 3/Mini 3 Pro, 6 Pack CPL ND8 ND16 ND32 ND64 ND128 Neutral Density Filter Drone Lens Accessory, Multi Coated HD Optical Glass, Aluminum Alloy Frame 【Lightweight Design】 The filter frame is made of aviation aluminum alloy, and the edge of the frame adopts CNC non-slip design, which is easy to install and disassemble. It weighs only 1.2g without affecting drone calibration and balance. 【30-layer Optical Coating】 Made of imported AGC high-definition optical glass, a double-sided, 30-layer nano-coating process can reduce glare and ghosting and block UV rays from 300nm to 380nm while ensuring accurate color reproduction. Waterproof, oil-proof, and scratch-proof. 【CPL Filter】Enhance color and contrast, especially for white clouds and blue sky shooting, and remove glare from water and glass by rotating the CPL filter. Helps capture clearer, more detailed images. 【ND Filter】 Reduce the shutter speed in bright conditions and the amount of light entering the camera sensor, allowing you to capture the natural effect you want in your footage. 【Package Include】 1 x filter case; 1 x 6-pack of CPL, ND8, ND16, ND32, ND64, ND128 filters; 1 x lens cleaning cloth.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41vb4PwX92L._AC_.jpg',
#   'rating_number': 282,
#   'price': 50.49,
#   'average_rating': 4.7},
#  {'preprocessed_data': "CHOKOVIE Smart Watch(Call Receive/Dial), AI Voice Controls, Fitness Tracker Watch with Heart Rate Blood Oxygen Meter, Step Counter 5ATM IP68 Waterproof Smartwatch for Men Women, Gold 【Call Receiving/Dialing】After connecting to Non-Bluetooth, you can directly dial the phone number on the watch's screen to make a call. Whether you're exercising or driving, your phone can slide onto your smartwatch in time for incoming calls. In addition, you can also listen to music directly through the smart watch, enjoy a colorful and intelligent life. 【Smartwatch for Men Women】Smartwatch is equipped with 1.3 inch HD clear color touch screen, so that you can enjoy smooth experience and view time and date easily.Fitness watch features 5 customized displays, you can also customize the watch face to show your personality. 【Activity Tracking & IP68 Waterproof】The smart band provides 5 sport modes records your all-day activities, it helps you better understand specific activity data, such as steps, calories burned, distance, etc. With the technology of IP68 waterproof, the smart watch could be worn normally in daily hand washing and swimming. 【Your Health Monitor】This fitness watch records deep sleep,light sleep and sleep time, tracks your sleep quality status to get a better understanding of your health. The Green light and infrared of the watch are detecting for heart rate, blood oxygen and blood pressure, you could get more specific health data. 【Powerful Battery Life & 12-Month-Guarantee】The fitness tracker is built-in a 240mAh high-capacity battery, which can be used for 7-10 days and let you get rid of the battery life anxiety.If you have any problem about the smart watch please contact us, We will take all responsibility within 12 months.Our products are required Bluetooth connection with smartphone( Android 4.0 or ios8.0 or higher) , the lower version of the system is not compatible with our app.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/51rwhkuE-TL._AC_.jpg',
#   'rating_number': 464,
#   'price': 35.99,
#   'average_rating': 3.7},
#  {'preprocessed_data': 'RJ45 Ethernet Splitter,NOBVEQ RJ45 1 Male to 3 x Female LAN Ethernet Splitter Adapter Cable Suitable Super Cat5, Cat5e, Cat6, Cat7 LAN Ethernet Socket Connector Adapter ',
#   'first_large_image': 'https://m.media-amazon.com/images/I/31FtmPBijUL._AC_.jpg',
#   'rating_number': 440,
#   'price': nan,
#   'average_rating': 3.4},
#  {'preprocessed_data': '40 Pcs Silicone Cable Ties Reusable Holder Strap Cord Ties Adjustable Cable Straps Multipurpose Charging Cable Organizer for Fastening Cable Charging Cords Wires (Black, White, Gray, Pink, ) Ample Quantity and Different Colors: the package contains 40 pieces of silicone cable ties in 4 different colors, including black, white, gray and pink, and each color has 10 pieces, ample quantity and various colors to meet your diverse needs Reliable and Long Lasting: the cable straps are made of quality silicone material, which is soft and flexible, reliable and firm to use, not easy to fray, break or fade, reusable and long lasting Proper Size: the silicone cable organizer measures approx. 11 cm/ 4.3 inches in length and approx. 1.2 cm/ 0.5 inches in width, which is lightweight and portable to carry around; The charging cable keeper is designed with a buckle with different gears at the bottom, so that you can adjust it to different lengths according to the size of your item Useful Gifts: the silicone cord ties can be applied as useful and practical gifts for engineers or people who work in electrician related industries, and you can also share with your friends, colleagues, or families, etc., helping them do their jobs better Versatile Application: the cable organizer straps can be widely applied for storing and finishing most kinds of wire supplies, such as cable, telephone line, TV cable, microphone line, computer line and more, which can be tied up stably',
#   'first_large_image': 'https://m.media-amazon.com/images/I/51WAX1-u5lL._AC_.jpg',
#   'rating_number': 271,
#   'price': 10.99,
#   'average_rating': 4.7},
#  {'preprocessed_data': 'NotoCity 22mm band for Fenix 7/Fenix 6/Fenix 5 Quickfit Watch Band Fenix 5 Plus Silicone Wristband Fenix 6 pro Sports Smartwatch Band Buckle closure ☛Notocity 22mm bands fit for Fenix 7/Fenix 5/Fenix 5 Plus/Fenix 6/Fenix 6 Pro/Forerunner 935,/Forerunner 945/exip/Approach S60/Quatix 5/Instinct 2/Instinct Esports/MARQ Golfer/Approach S62 smartwatch ☛Compatible Size: Fits wrist between 7.08"-9.25" (180mm-235mm) , ▶Please confirm your wrist size before choose ☛Fit Securely: Metal parts made of hypoallergenic nickel stainless steel and high quality Soft Environmental silicone, No peculiar smell and harmless, No Extra Edge to hurt your hands ☛Design: Quickfit and Smooth face design, simple and elegant; Equipped with two fixing rings to protect it from slipping off, more stable and more comfortable ☏ Quality assurance: If you find that the size is incorrect after purchase, please contact our immediately, we will help you find the best solution to solve.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41-whe35ZPL._AC_.jpg',
#   'rating_number': 118,
#   'price': 13.99,
#   'average_rating': 4.7},
#  {'preprocessed_data': 'Wireless Digital Microscope, SKYBASIC 50X-1000X Magnification WiFi USB HD Portable Handheld Pocket Microscopes Camera with 8 Adjustable LED Compatible with iPhone iPad Android Windows Mac Computer ☁【WiFi & USB Microscope】This is a wireless portable digital microscope with a WIFI hotspot, designed to connect to Android or iOS mobile phones and tablets, and also supports USB to connect to Windows or Mac computers for easy use in different fields. ☁【HD Image & LCD Screen Design】2 million pixel high-resolution images microscope, 1920*1080P high-definition image quality for smartphones, 1280*720P for computers, the larger the screen, the better the view. The unique LCD screen design, in the case of wifi connection and charging, emits blue and green indicators (red light is displayed when the battery is low), clearly knowing the battery status and wifi connection, and the user experience is more high-end. ☁【8 LED Light & Easy to Focus】8 led lights and a soft light design, provide enough light and the best clarity, long-term observation will not hurt the eyes. The 360-degree rotating focus wheel allows you to focus quickly and use it anywhere. Note: The best focal length for microscope imaging is 2-60mm, please rotate the focusing wheel left and right when observing blur. ☁【Take Pictures and Videos】Not just a microscope, you can zoom in and out, but also take photos and videos with one click. It is easy to capture excellent microscopic details, and amazing wonderful moments can be saved in the folder of the device and viewed anytime, anywhere, and it can be very useful in recording the change cycle of the observed object. (Note: The take photo and zoom in and out buttons on the microscope body only apply to the WIFI connection.) ☁【Portable Pocket Microscope】Lightweight and compact, with a cylindrical body design, it can stay upright on flat ground at any time. With a portable bracelet, it is easy to carry around. This is a great option for taking kids outdoors to explore, as a teaching tool, or for anyone interested in learning about skin, hair, plants, insects, jewelry, and coins. Note: This microscope is not a traditional microscope and is not suitable for professional biologists! ☁【WIFI connection for Android and IOS】1. Download the "MAX-VIEW" software from Google Play or APP Store. 2. Press and hold the power button to turn on the microscope. 3. Open the APP interface and randomly enter into the settings to find "MAX-VIEW" (no password).4. Click to return to the software after the connection is successful, and you can open your microscopic world, which is very convenient to use (the blue light of the microscope display is always on after connection) ☁【Friendly Multi-function APP】After downloading the “MAX-VIEW” app, there will be a connection video and FAQ analysis, a unique horizontal screen and split screen switching function, multi-angle observation, screen lock function to prevent accidental touch during operation, mirroring and lighting adjustment, you can also check the power status in real-time, go out It is more convenient to carry, and the powerful APP makes the microscope and equipment perfectly connected, and the use is smoother. ☁【USB Connection for Computer】1.For the win 10/11 system, directly search for the software "Windows Camera" 2. For win7/8/, please download "AMCAP" to start using. 3. For MacOSx11.0 or later, please use the bundled software Photo Booth or Quick Time of Macbooks directly Player. 4. Note: Please disable the default laptop camera in Windows! And you have to change the camera\'s privacy settings, which need to be changed to allow access. ☁【What You Will Get】1x microscope, 1x USB cable (adapter not included), 1x user manual, 1-year return service for quality problems, 100% satisfied 24 hours professional after-sales service. ☁【Great Compatibility】This handheld digital microscope is compatible with most devices. Mobile phones: Android6.0+, IOS9.0+. computers: Windows vista7/8 ...
#   'first_large_image': 'https://m.media-amazon.com/images/I/4117UfqICXL._AC_.jpg',
#   'rating_number': 256,
#   'price': 33.99,
#   'average_rating': 4.5},
#  {'preprocessed_data': 'YIMIKOL Kids Case for iPad 9th Generation/iPad 8th Generation/iPad 7th Generation, iPad 10.2 inch Case 2021/2020/2019, Heavy Duty Shockproof Rugged Protective 10.2" Cover for Boys Girls (Black+Gold) 🍎【Compatible Models】 YIMIKOL case compatible with 10.2 inch new ipad 9th generation (2021 Released)/iPad 8th Generation (2020)/iPad 7th generation (2019) . Model Number: (A2602 A2603 A2604 A2605/ A2270 A2428 A2429 A2430/ A2197 A2198 A2200). NOT fits for any other devices. 🍎【3 Layer Shockproof Design】 This kid case for iPad 9th generation made of durable hard PC+silicone, 3-layer full body protection structure, provide a perfect protection & anti-scratch. NOTE: This ipad 10.2 inch case WITHOUT built-in screen protector. 🍎【Functional Kickstand】 Case for 9th generation ipad 10.2 inch built-in convenient kickstand with 2 angles: Typing & Viewing angles. Premium case for ipad 7th generation is convenient for studying, gaming, watching video, etc. 🍎【Precise Cutouts】 The kids case for ipad 8th generation is easy to access all buttons, speakers, cameras through the precisely-cut openings. Especially the charging port with rubber flap which can keep dust out. It\'s also a nice and practical gift for your kids and friends. 🍎【What You Get】 If you have any questions of our case for ipad 7th/8th/9th generation 10.2 inch, please feel free to contact us at any time. We sure all the question can be solved properly.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/51IZaXZnj7L._AC_.jpg',
#   'rating_number': 436,
#   'price': 19.99,
#   'average_rating': 4.5},
#  {'preprocessed_data': 'Aroncent Portable Binoculars 3x2.5 Magnification for Theatre Sports Concert Outdoor Camping Color Choice, Base Metal Stylish and modern opera glasses with handle, elegant shape, convenient and practical, suitable as a gift. Beautifully designed with polished alloy and K9 glass, vintage and refined, durable. Vintage opera glasses glasses for theater musical concert, choose the high quality lens, 3X2.5 magnification, especially suitable for theater. The handle can be broken up and down according to your favorite, choose the right way to use the telescope. (Note: the handle can not be rotated angle) Since this product is not a professional optical lens. It is more ornamental compared with the practicality. It is a perfect Birthday Christmas Halloween Thanksgiving Day Gifts.e this product is not a professional optical lens. It is more ornamental compared with the practicality. It is a perfect Birthday Christmas Halloween Thanksgiving Day Gifts. Opera glasses are small and delicate, easy to carry. The package comes with a soft protective bag and cleaning cloth, convenient to store and protect opera glasses. Suitable for a variety of events, such as opera, drama, live performances, etc.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41zMamJfvcL._AC_.jpg',
#   'rating_number': 157,
#   'price': 29.99,
#   'average_rating': 3.9},
#  {'preprocessed_data': 'Apple Earbuds Headphone with Lightning Connector [Apple MFi Certified] Wired Earphones with Built-in Microphone and Volume Control for iPhone 14/13/12/11/SE/X/XR/XS/8/7,Support All iOS 🎵【Widely Compatibility】These Apple Earbuds are compatible with all lightning connector devices and widely compatible with iPhone 14/13/12/11/X/XR/8/7, iPad, and Pod, ensuring that you can use them with your favorite device. 🎵【Remote and Microphone】Use the remote to adjust the volume, control the playback, and answer or end calls with a pinch of the cord, while the built-in microphone allows you to call hands-free, making them easy to use. 🎵【High Quality Sound】The earbuds use 100% copper core to provide lossless digital sound quality, supporting 48KHz and 24-bit audio output for better sound transmission stability and fidelity, while the ergonomic noise reduction in-ear headphones minimize the noise in the surrounding environment and bring you a better music experience. 🎵【Wired Bluetooth Headset】 As this earphone is a Bluet00th connectivity version. You need to turn on the Bluet00th in your Phone or Pad, then plug the earphone in to connect them. When next time you use the earphone again, it will automatically connect to your device in 2-8 seconds. ATTENTION: This is very important, it is the first step that must done. 🎵【Risk-free Guarantee】With our 12 months quality assurance service and 7*24 online support, we are committed to providing satisfactory service to all our customers, ensuring that any questions or concerns are quickly resolved.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/31NcKi417vL._AC_.jpg',
#   'rating_number': 2154,
#   'price': 8.99,
#   'average_rating': 4.6},
#  {'preprocessed_data': 'co2CREA Soft Silicone Case Replacement for Bose SoundLink Flex Bluetooth Portable Speaker Carmine Red Case co2CREA soft silicone Bose speaker travel case replacement for Bose soundlink flex Bluetooth portable speaker. The Bose flex speaker soft case is made of soft silicone material, which is sturdy and durable., protect your Bose speaker soundlink flex Bluetooth portable speaker from drops and bumps. This Bose wireless speaker soft protection cover perfect for Bose soundlink flex wireless speakers with Bluetooth outdoor portable speaker, and the soft silicone case is designed to pulled and distorted, the Bluetooth Bose speakers is impossible to slip out of the case in use. co2CREA silicone case for Bosé soundlink flex small phone speaker, it is lightweight and compact to fit in your backpack, carry-on or luggage, it takes up a lot less space. Soft silicone case has accurate charger port cutout, so there is no need to remove the silicone protective cover from the Bose flex speaker during the charging prcess. co2CREA Bose speakers portable wireless silicone cover has a comfortable carabiner and shoulder strap , so that the Bluetooth Bose speakers portable wireless speaker will easy to carry, you can simply hold it wherever you go and enjoy music anywhere. For sale is CASE ONLY! (Bose waterproof speaker and Bose sound link speaker accessories are not included)',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41KzOne9wWL._AC_.jpg',
#   'rating_number': 1629,
#   'price': 18.99,
#   'average_rating': 4.7},
#  {'preprocessed_data': 'ECOSUSI Briefcase for Women Messenger Backpack PU Leather 14 inch Laptop Bag Satchel Computer Bag for College Business Travel Pu Leather Imported Offers Versatile Carrying Options: Comes with 2 adjustable and removable straps,you can easily convert to backpack, shoulder bag,crossbody bag or handbag,great for work, business trip, meeting, office job, interviews, teaching, banquet, party, shopping or everyday use Large Capacity: 15 x 13 x 4.7 inches (L x H x W).Internal compartments which is for 14 inches laptop and ipad,the other compartment is fit for documents,wallets,cables,make up or other daily accessorices,3 small slip pockets,1 front pocket for accessories you want to get quickly,1 small zippered compartment that helps you organize your valuables Detachable Bow: Unique removable bow decoration,can be matched with bow ties according to different occasions. Vintage gold-tone metal hardware makes you be able to use this bag for many years to come.suitable for various festivals as gifts High Quality Brand: ECOSUSI choose plain PU leather is fashion and commuter tone.Environmentally friendly material: Made of durable vegan leather which don’t hurt animals After-Service: ECOSUSI provide high-quality products and perfect after-sales service,if you have any problem,please contact us by email,we will solve the problem for you as soon as possible.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/31H2Uhg3XmL._AC_.jpg',
#   'rating_number': 136,
#   'price': 52.99,
#   'average_rating': 4.5},
#  {'preprocessed_data': "Nasuque Bluetooth Keyboard for Mac OS, Wireless Rechargeable Slim Multi-Device mac Keyboard with Number Pad Compatible for MacBook Pro/Air, iMac, iPhone, iPad Pro/Air/Mini -Black and Gray 【SUPPORT 3 DEVICES SIMULTANEOUSLY】This Bluetooth keyboard for mac supports up to three devices simultaneously and easily switch between them. 【MAC-COMPATIBLE KEYBOARD】Work with all Bluetooth devices with iOS or Mac OS system, including MacBook Pro/Air, iMac, iPhone, iPad Pro/Air/Mini, meeting Apple users' expectations. 【ULTRA-SLIM DESIGN】Made of durable material, this wireless keyboard macbook air has ultra-slim design, the thinnest part is just 0.16 inch. And with a stable scissor mechanism beneath each key, as well as a low profile, it provides a remarkably comfortable and precise typing experience. 【LONG CONNECTION DISTANCE】Advanced Bluetooth technology provides a cable-free, clutter-free and stable connection, long operating distance, about 8m (26ft). 【RECHARGEABLE BATTERY】With built-in lithium battery, this wireless imac keyboard can be easily recharged through USB cable, no need to change the battery. If you have any problem, you can feel free to contact us.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/417uM2VqsLL._AC_.jpg',
#   'rating_number': 658,
#   'price': 23.99,
#   'average_rating': 4.2},
#  {'preprocessed_data': 'Amaitree Lightning Cable 6Ft[Apple MFi Certified]Nylon Braided 3A Fast Charging iPhone Charger Cable,Lightning Cord for iPhone 14,Compatible with iPhone 14/13/12/11/Mini/Pro/Pro Max/XS/XR/8/7/6/5-Red 【NEW MFi Certified Connectors】-Use the latest C89 Apple terminal is more durable and stable than original C48.Ensure that you and your devices are safe while charging. 【Nylon Braided Over-mold aluminum housing More Durable】-Military fiber has high strength,is a soft,powerful and durable material,which can increase the tensile force by 200%.The high-quality nylon braid increases durability, is free of tangles,and has a bending life of 15,000+. 【Apple MFi Certified Lightning Cable】-Original 8 Pin connector with a lightning end.Enjoy lightning-fast data syncing and charging.MFi certified by Apple themselves to offer superior peace of mind. Use with any of your Apple devices with no safety or data concerns. 【Appropriate-Length 6Ft】-With the 6Ft length,you can lie on the couch or sofa and use your devices while you are charging at the same time. 【Amaitree Factory】-Amaitree factory joined MFi project of Apple Inc. in 2013,possession 17 years experience of design, production and R&D committed to providing each customer with the highest standard of customer service that provide more quality reliable to your digital life.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41MTrlKfZsL.jpg',
#   'rating_number': 282,
#   'price': 6.95,
#   'average_rating': 4.5},
#  {'preprocessed_data': "BANDAI SPIRITS #44 Cyclase's Schwalbe Custom Iron- Blooded Orphans, Hobby HG IBO 1/144 The vernier block attached to the rear skirt rotates in two places. The vernier block is removable. Comes with characteristic weapons such as a dedicated hand gun and shield. Model Building kit",
#   'first_large_image': 'https://m.media-amazon.com/images/I/41O+-NEuNsL._AC_.jpg',
#   'rating_number': 179,
#   'price': 20.75,
#   'average_rating': 4.3},
#  {'preprocessed_data': "Wireless Keyboard and Mouse Combo - Samsers Ultra Slim Rechargeable Dual-Mode (Bluetooth 5.0x2 +2.4G) Silent Keyboard and Mouse Set, Multi-Device Full-Size Compact Design for MacOS/iOS/Android/Windows 【2.4G & Bluetooth 5.0 Keyboard and Mouse】 Samsers multi-device wireless keyboard and mouse supports 3 devices to connect at the same time, seamless switching without delay (2.4G wireless + Bluetooth 5.0 + Bluetooth 5.0). Plug-and-play 2.4G receiver, no need to install additional software or drivers, instant connection and worry-free use! You can type, switch and keep typing! 【1 Second Switch to 3 Device】 Samsers Bluetooth keyboard and mouse work seamlessly with Mac OS, Windows, iOS, and Android systems. Just press one key to switch back and forth between 3 devices (keyboard and mouse need to be switched separately). Compatible with Mac OS/iOS 10.12 or above, Windows 8/10 or above, Android 4.3 or above. 【Type-C Charging & Upgrade Chip】 Built-in 280mAh (keyboard)/300mAh (mouse) battery. Upgraded power-saving chip, auto-sleep function and Tpye-C fast charging technology. Just 2 hours of charging, it can work continuously for 90 hours (keyboard)/ 60 hours (mouse), or stand by for 190 days (keyboard)/ 330 days (mouse). Samsers wireless keyboards and mice last much longer than others. Eliminate the trouble of frequent charging! 【Ultra-Thin & Ergonomic】 Ultra thin gray matte keyboard, made of durable ABS+PC material, lightweight but stable. Ergonomic design of the mouse with 4 adjustable DPI, more in line with your habits, reduce wrist fatigue. Refined elegant appearance, excellent touch and clean look make it the perfect match for your desktop! 【Excellent Layout & Button Design】 Low-profile scissor switch button has excellent touch and sufficient button travel, provides satisfactory feedback with each stroke. Standard keyboard size provides quiet, accurate and fast typing. Standard numeric keypad and rich multimedia button layouts, also help you greatly improve your workflow and efficiency! 【100% Satisfaction Service】 Samsers provides you with 24-hour Email Response & 100% Satisfaction Service & Lifetime Technical Support. If you have any questions, please don't hesitate to contact us!~",
#   'first_large_image': 'https://m.media-amazon.com/images/I/41id5jOTAtL._AC_.jpg',
#   'rating_number': 194,
#   'price': 48.99,
#   'average_rating': 4.5},
#  {'preprocessed_data': "Wireless CarPlay Adapter for Factory Wired CarPlay, Wireless Dongle for CarPlay Cars from 2017 and iPhone iOS 12+, Plug & Play, Online Update (White) 🚗 【Carplay Wireless Adapter】2023 innovative wireless carplay adapter converts your car to wireless, you don’t need to replace existing head or reconfigure the center console. With the wireless dongle, it can keep the default car control features, such as navigation, music playing, Siri assistant, phone calls, etc. 🚗 【Plug & Play Easy to Use】Connect wireless carplay adapter to your car’s USB port that powers wired carplay, these devices leverage the WiFi and Bluetooth on your iPhone and serves as a receiver for your car. When you enter and turn on your vehicle, the carplay adapter will auto connect to your iPhone after the first time connection succeeded, even if your phone is in your pocket or backpack. 🚗 【Universal Compatibility for Cars】Our carplay wireless adapter works with all cars that have factory-installed CarPlay system. It comes with 2 cables( USB-C to USB-C, USB-C to USB ) fit for different car center consoles. Wireless connection supports iPhone IOS 12 version and newer that are capable of running carplay. 🚗 【Stable and Uninterrupted CarPlay Experience 】 Wireless carplay dongle that allows you to use CarPlay feature in your car without needing to plug in your iPhone, provide great reliability, a solid and uninterrupted connection every time. You can access most of your iPhone's features and apps, such as phone calls, texts, music, and more, from the touchscreen display in your car wirelessly. 🚗 【Tips You Should Know】Be sure that your car has factory-installed CarPlay, this model doesn’t support Android Phones. Package includes: 1 x Wireless CarPlay Adapter, 1 x USB-C to USB Cable, 1 x USB-C to USB-C. We provide 24H*7D service, please feel free to contact us if there any problems/questions.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/31jFvEM26gL._AC_.jpg',
#   'rating_number': 280,
#   'price': 49.99,
#   'average_rating': 4.3},
# ...
#   'first_large_image': 'https://m.media-amazon.com/images/I/41LJPqMZsKL._AC_.jpg',
#   'rating_number': 1126,
#   'price': nan,
#   'average_rating': 4.5},
#  {'preprocessed_data': "Fullant Kids Tablet 7 inch,Android 12 Tablet for Kids,32GB ROM 128GB Expand,Kids Software Pre-Installed,Bluetooth,Dual Camera,Toddler Tablet with Shockproof Case 【Newest Android 12 OS 】Fullant tablet for kids is equipped with the latest version of GMS-certified Android 11 GO OS, which is safer and faster than Android 10 and eliminates unwanted ads. The 1.6GHz quad-core processor is 20% faster than regular processors. And supports WiFi, Bluetooth, etc. 【Kids' Safety & Parental Controls】Fullant kids tablets can ensure kids' safety online with 2 types of parental controls. Using the Kidoz interface, parents can limit screen time, set educational goals, and filter harmful web pages. With the FamilyGroup app, you can check on your kids activity remotely at any time, including how often and how long the tablet was used, to understand your kids usage habits better. 【Learning, Playing and Reading Included】You can download various YouTube and Netflix and kids games apps from Google Play Store, 32GB internal storage space, which can be expanded with a microSD slot up to 128GB additional storage.Our kids tablet have a 3500mah rechargeable battery, up to 8 hours of reading, browsing the web, video watching, and music listening,a good companion for children to play and learn! 【HD Display and Eyes Protection】Fullant Kids tablet has a 1024x600 IPS HD display touchscreen is designed with low blue light technology. It can automatically adjust the brightness to a comfortable reading experience.With one click you can enter reading mode, reducing screen flicker and eye damage caused by irritating blue light,creating a healthy reading and gaming environment for your children! 【Special Design of Kid-proof Case】Our children's tablet case is made of special soft silicone material, which is durable and odorless, so you don't have to worry about harming your child's health. It can protect children's tablet well, no matter indoor or outdoor, there is no need to worry about accidental collision or impact. The child case also comes with a built-in kickstand to free your child's hands! Fullant offer a 30-day money-back guarantee and 12 months warranty for quality issue. To ensure the quality of our service, please contact us if you have any questions about this tablet.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/41ViI7nLKyL._AC_.jpg',
#   'rating_number': 168,
#   'price': 49.99,
#   'average_rating': 4.0},
#  {'preprocessed_data': "LG UltraWide FHD 26-Inch Computer Monitor 26WQ500-B, IPS with HDR 10 Compatibility and AMD FreeSync, Black 21:9 Full HD (2560 x 1080) display offers more screen space than similar 16:9 resolution displays, allowing you to run and view multiple windows, thumbnails, and more at once With HDR 10 support and color performance with 99% coverage of the sRGB spectrum, this color-calibrated monitor is a great solution for photographers, graphic designers, or anyone looking for highly accurate color Protect your eyes and minimize eye fatigue during long work sessions with Reader Mode's blue light reduction and Flicker Safe, virtually eliminating onscreen flicker. OnScreen control allows you to make display adjustments using your mouse* AMD FreeSync manages refresh rate, reducing screen tearing, flicker, and stuttering for an effortlessly smooth gaming experience with supported video cards such as the AMD Radeon series Dynamic Action Sync helps reduce input lag to help you respond to on-screen action quickly. Black Stabilizer dynamically brightens dark scenes to help you find enemies in the dark. Enhance your accuracy in firefights with the Crosshair feature",
#   'first_large_image': 'https://m.media-amazon.com/images/I/41raHM0UySL._AC_.jpg',
#   'rating_number': 3833,
#   'price': 116.84,
#   'average_rating': 4.6},
#  {'preprocessed_data': "0.6''x32FT Reusable Cable Ties with 50 Metal Buckles, ApexOne 0.6 inch Wide Hook and Loop Straps, Adjustable Cut-to-Length Cinch Straps Cord Management Fastening Straps Wire Organizer & Storage 【Cut into Length】You can freely cut it into the length you want to make the right cinch strap to organize or store messy items, no need to pay for wrong size or extra size again. In our store there are 1 inch wide, 2 inch wide for your reference if you think 0.6’’ wide is not durable enough. 【Reusable & Durable & Heavy Duty】This securing straps are made of 100% nylon material, with strong metal buckle, Can hold up to 30lbs, and Can be reused to avoid waste. Help you save more money to tidy items. 【Easy to Use】Hooks and loops are intertwined on the same side, just pass the strap through the metal square buckle, then reverse the bonding, finally cut to the appropriate length. Within 8-10 seconds you can complete this process. This usage makes you fasten items more tightly and easily. 【Multi-Purpose Applications】This fastener is perfectly suitable for bundling small or large items, such as flowers, trees, hoses, pipes, tubes, bike rack, water bottles, skis, poles, umbrellas, sports equipment, molle systems, camping gear, boats, golf clubs, kayaks, etc. Great for use around the home and office indoor or outdoor. 【Sew on】This non-adhesive straps can also be widely applied in sewing, DIY craft, clothes, shoes, school bags, backpack bags, handbags and so on.",
#   'first_large_image': 'https://m.media-amazon.com/images/I/51Vo9Z-08cL._AC_.jpg',
#   'rating_number': 441,
#   'price': 9.99,
#   'average_rating': 4.5},
#  {'preprocessed_data': 'ALLBYT iPhone Flash Drive1TB Memory Stick, USB 3.0 iPhoto Stick Thumb Drive External Storage USB Flash Drive Compatible with iPhone and iPad,Android and Computers -Pink Phone flash drive photo stick directly plugs into your phone port and USB port,85 MB/s reading and 35 MB/s writing speed in USB end. Makes files transmission much easier on the go. Format-Friendly Streaming APP-The free "Y-DISK" APP supports all major video and music formats so you can stream directly from the thumb drive, saving you precious space and time. Memory Photo Stick USB flash drives provide more external space Compatible for Phone, Android and PC, standard USB ports,phone ports and andriod ports, amazing transfer speed, just plug in drive and easily take photos, videos and other files from phone onto the flash drive,from the flash drive.let the phone no longer worry about lack of memory problems. User Friendly App With More Features-1.Take photos, videos and audios directly to external storage; 2.Thumb flash drive can open compressed files directly for easy browsing; 3.phone flash drive storage drive makes it easy to back up and manage files; 4.Encrypt single files in the flash drive; 5.memory stick can backup and restore contacts at one click; 6.photo stick flash drive Share files with social medias and other Apps. COMPATIBILITY & 12 MONTHS WARRANTY Compatible with any phone,Computer OS Support Mac OS X v10.6+, Windows 7/8/10, Android Phone with OTG Function. 1 Year Warranty offered by ALLBYT.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41U36NUl7vL._AC_.jpg',
#   'rating_number': 161,
#   'price': 30.99,
#   'average_rating': 4.1},
#  {'preprocessed_data': 'Bulletpoint Metal 4-Hole AMPS Base Mount with 20mm (0.787 inches) Mounting Ball [METAL CONSTRUCTION] our 4-hole 20mm AMPS mount is made from laser cut aluminum & features a thin rubber strip underneath to help reduce unwanted vibrations and prevent scratching to the mounting surface. [SOLID FOUNDATION FOR DEVICES] easily attach mounting arms or device holders to the sturdy integrated 20mm AMPS ball dash mount. [INCLUDED INSTALLATION HARDWARE] 4x bolts, 4x washers and 4x nylon locking nuts are included to make installation fast and easy. [INDUSTRY-STANDARD AMPS PATTERN] our ball mount plate features the standard 4-hole 30mm x 38mm configuration compatible with 3rd party AMPS plates and mounts. m COMPATIBILITY] our 20mm AMPS Ball is compatible with the entire range of 20mm (0.787 inches) Bulletpoint Mounting Solutions mounting arms and device holders.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/31QdSjxpBqL._AC_.jpg',
#   'rating_number': 143,
#   'price': 10.99,
#   'average_rating': 4.8},
#  {'preprocessed_data': "Vinyl Record Player Turntable with Speakers (36W) Wireless Bookshelf HiFi Stereo System Support USB Recording Magnetic Cartridge Built-in Phono Preamp RCA Output Counterweight Iron Platter Belt Drive HIFI Stereo Speakers: Turntables for vinyl records come with 2*18W bookshelf speakers, which produce a balanced studio sound with deep bass, low distortion and amazing quality. The built-in pre-amplifier allows you to connect to your speakers or stereo system via RCA jacks Moving Magnetic Cartridge: Record players for vinyl with speakers include high-quality moving magnetic cartridge and stylus. It better reproduces the details and realism found on records, producing rich, warm audio and excellent sound clarity that many inexpensive models can’t match Wireless Streaming Input & Vinyl Recording via PC: This vinyl player allows you to listen to records via smart phone, tablet, computer or other compatible devices. It also supports USB to PC encoding, convert vinyls into MP3 digital files via computer and playback Premium Audio & Video Turntables: Adjustable counterweight, essential for any classic turntable, allow independent and accurate adjustment of the tracking force of the needle. Iron platter produces an even inertial mass, together with the statically balanced aluminum tonearm, greatly reducing the vibration of record player Natural Wood Appearance Aesthetics: After a simple installation, this belt-driven 2-speed (33 1/3 & 45 RPM) vintage record player will match your furniture perfectly. They won’t take up too much space in the room and won't clash with the rest of your home decor",
#   'first_large_image': 'https://m.media-amazon.com/images/I/4121xH5Tj6L._AC_.jpg',
#   'rating_number': 2579,
#   'price': 279.99,
#   'average_rating': 4.4},
#  {'preprocessed_data': 'Tiksounds Wireless Earbuds, Bluetooth 5.3 Headphones, Bluetooth Earbuds with LED Display, 60 Hrs of Playtime, IPX7 Waterproof, Stereo Sound, Over Ear Earphones with Mic for Sports Running Workout Gym LED Digital Power Display: Wireless earbuds with LED display to clearly show the battery level of the charging case and earbuds. 60 Hours of Playback: Up to 10 hours of listening time on a single earbuds, over 60 hours with charging case. Bluetoth 5.3 and Stereo Sound Quality: Bluetooth earbuds with Bluetooth 5.3 chip technology and 10mm drivers let you experience crystal clear HD stereo sound and powerful bass. Designed for Sports: The adjustable, firm-fitting ear hooks keep the earphones stable. Keeps you comfortable during a hard workout or run. IPX7 Waterproof: IPX7 rated waterproof earbuds with nano-coating technology to prevent sweat and rain from damaging the components of the wireless earbuds.',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41ohzPgqMnL._AC_.jpg',
#   'rating_number': 576,
#   'price': nan,
#   'average_rating': 4.4},
#  {'preprocessed_data': 'Garmin Edge® Explore 2, Easy-To-Use GPS Cycling Navigator, eBike Compatibility, Maps and Navigation, with Safety Features Easy-to-use GPS cycling computer with 3” high-resolution, glove- and rain-friendly touchscreen that’s visible even in direct sunlight Simple setup complete with preloaded road, off-road and indoor activity profiles that are ready to use right out of the box Ride like a local, whatever your bike type, with improved ride type-specific maps that highlight popular roads and trails, searchable POIs and even eBike routing See high-traffic roads directly on the map to help you stay aware as you ride and make informed choices for your route When connected to your compatible eBike, receive navigation guidance and alerts based on your bike’s battery status, assist level and range When paired with your smartphone, stay connected with the LiveTrack and GroupTrack features, smart notifications, rider-to-rider messaging and built-in incident detection (during outdoor rides) Built-in GPS tracks how far, how fast, how high and where you ride Compatible with sensors (sold separately) for monitoring heart rate, bike speed, bike cadence and more Compatible with Varia cycling awareness devices (sold separately), including smart bike lights and rearview radar, to detect cars and alert drivers During indoor rides, pair with your smartphone, and control music directly from your Edge device',
#   'first_large_image': 'https://m.media-amazon.com/images/I/41CIVX2Y0IL._AC_.jpg',
#   'rating_number': 115,
#   'price': 249.99,
#   'average_rating': 4.3},
#  {'preprocessed_data': 'Razer Leviathan V2 X: PC-soundbar-with Full-Range Drivers - Compact Design - Chroma RGB - USB Type C Power-and Audio Delivery - Bluetooth 5.0-for PC,-Laptop, Smartphones, Tablets-&Nintendo Switch PC Soundbar with Full-Range Drivers: Armed with two full-range drivers and two passive radiators, the Leviathan V2 X delivers a riveting audio experience across all your entertainment.Waterproof : No Compact Desktop Form Factor: The most compact soundbar in our Leviathan V2 range fits perfectly beneath your monitor for a clutter-free desktop USB Type C Power and Audio Delivery: Powered by a single USB Type C cable to deliver dynamic audio with a volume output of up to 90Db and enables for an easy setup Bluetooth 5.0: Enjoy smooth, stutter-free sound with a low-latency Bluetooth connection, as you switch seamlessly between your PC and your preferred mobile device that’s conveniently paired via the Razer Audio App Powered by Razer Chroma RGB: With 14 lighting zones, countless patterns, dynamic in-game lighting effects—experience full RGB customization and deeper immersion with the world’s largest lighting ecosystem for gaming devices Razer Audio App and Razer Synapse: From customizing RGB lighting to toggling between audio devices, tweak the soundbar to best suit your needs with software designed to give you more control',
#   'first_large_image': 'https://m.media-amazon.com/images/I/31hn-sw+HkL._AC_.jpg',
#   'rating_number': 460,
#   'price': 99.99,
#   'average_rating': 4.2}]

# %%
pointstructs = []
for i, data in enumerate(data_to_embed):
    embedding = get_embeddings(data["preprocessed_data"])
    pointstructs.append(
        PointStruct(
            id=i,
            vector=embedding,
            payload={
                "text": data["preprocessed_data"],
                "first_large_image": data["first_large_image"],
                "rating_number": data["rating_number"],
                "price": data["price"],
                "average_rating": data["average_rating"]
            }
        )
    )

# %%
qdrant_client.upsert(
    collection_name="Amazon-items-collection-01-hybrid",
    wait=True,
    points=pointstructs
)
# Out:
# UpdateResult(operation_id=2, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
from qdrant_client.models import Filter, Prefetch, FieldCondition, MatchText, FusionQuery

def retrieve_data(query, k=5):
    query_embedding = get_embeddings(query)
    
    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-01-hybrid",
        prefetch=[
            Prefetch(
                query=query_embedding,
                limit=20,
            ),
            Prefetch(
                filter=Filter(
                    must=[
                        FieldCondition(
                            key="text",
                            match=MatchText(text=query)
                        )
                    ]
                ),
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k
    )
    
    return results

# %%
retrieve_data("earphones").points
# Out:
# [ScoredPoint(id=2, version=2, score=1.0, payload={'text': 'Active Noise Cancelling Wireless Earbuds, Bluetooth in-Ear Headphones Built-in 4 Mic ENC Call, Deep Bass Ear Buds,IPX6 Waterproof Stereo Earphones for iPhone,Samsung,Laptop (Blue) ♪【ANC Noise Cancelling&Game Mode】: These premium noise-canceling earbuds adopts professional audio active noise canceling technology, and the binaural microphone blocks environmental noise and enhances the voice experience. M48 wireless earbuds are built to provide the exceptional mobile gaming audio experience with an ultra-low 45ms latency.Taps 5 times to enter game mode,through quick sound effect and ideal gaming audio you never miss any game sound effects. ♪【HiFi Stereo Sound & Superior Clear Call 】: Heaphones equipped with a high-sensitivity diaphragm and dual 13mm drivers to restore audio authenticity and voice dynamics, crystal clarity and deep resonance bass characteristics enable you to enjoy immersive sound quality. Call noise canceling brings you crystal clear calls, even in a noisy environment,true wireless in-ear earbuds can achieve a perfect call experience and stereo sound. ♪【LED Light Display & USB-C Fast Charging】: Dual digital LED power display outside of the case is to show the power level for the charging case and to remind you to charge in time by USB-C charge quickly. Put wireless earphones back in the charging case, and the display will flash that meaning earbuds are being charged. 350mAH battery capacity charging case can provide 4 times full charging for two ear buds, each earphone can last for 4H, you can use it for a day without worry. ♪【Upgrade Bluetooth 5.3 & Auto Pairing & Reminder】: Adopting the latest Bluetooth technology 5.3, True wireless earbuds Bluetooth 5.3 have a faster transmission rate, lower latency, providing a fast and stable connection and signal transmission (10 meters barrier-free). Due to the replacement of old and new packaging, you may receive the package of Bluetooth 5.1, but the product is the latest version of Bluetooth 5.3, thanks for your understand. ♪【Touch Control & Transparent Mode】: Easy touch control brings you a convenient operation experience when answering calls, skipping songs, and selecting different listening modes by wireless earbuds bluetooth. With the Transprency mode, you can hear what you want to hear, so you can listen and interact with the world around you. You can clearly hear an announcement of the airline or subway, as well as the sound around you, without taking off the headphones.', 'first_large_image': 'https://m.media-amazon.com/images/I/41gDQBYBnJL._AC_.jpg', 'rating_number': 147, 'price': None, 'average_rating': 3.9}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=11, version=2, score=0.5833334, payload={'text': "Hearprotek Sleep Earbuds Lightweight Soft Noise Reduction Earbuds Wired with Mic and Volume Control, 3.5mm Tangle Free Sleep Headphones for Side Sleepers, Snoring, Air Travel, Meditation, Relaxation [Super Comfy &Light Weight] Earphones are made from flexible silicone, which enables them to easily conform to your ear canal painless without bothering your ear. Super lightweight, only weighs 0.36oz (10.2g/pair), which are almost hardly feel them when sleeping，the best companion for side sleepers. [Double Layers Design & Noise Reduction] Sleeping earphones are adapted with double layers design to provide better noise reduction. You don't need have to sleep on your back, side sleeper also could get a good night. Earphone keeps the traffic noise, neighbour noise, the ticking of clock, office noise out of your ear, and the music will soothe the stress of all day. [Durable & Tangle Free] The earbuds are built in bulletproof tough wire which are durable and flexible. You don't have to worry about damage from your sleeping posture or entanglement. The 125CM extra long thin wire won’t restrict your movement as well. [Wide Compatibility] With 3.5mm jack plug, fits any standard audio device, you can easily fall asleep to your favorite music, audiobooks, podcasts and soothing sounds. [Multiple Button Control] Features with 3-button control, you can switch music and answer/reject phone call on your fingertip easily. You can soothe your tired mind and enjoy a restful sleep by listening to white noise or calming music.", 'first_large_image': 'https://m.media-amazon.com/images/I/31AeW1yns+L._AC_.jpg', 'rating_number': 2808, 'price': 10.99, 'average_rating': 4.3}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=22, version=2, score=0.5833334, payload={'text': 'Apple Earbuds Headphone with Lightning Connector [Apple MFi Certified] Wired Earphones with Built-in Microphone and Volume Control for iPhone 14/13/12/11/SE/X/XR/XS/8/7,Support All iOS 🎵【Widely Compatibility】These Apple Earbuds are compatible with all lightning connector devices and widely compatible with iPhone 14/13/12/11/X/XR/8/7, iPad, and Pod, ensuring that you can use them with your favorite device. 🎵【Remote and Microphone】Use the remote to adjust the volume, control the playback, and answer or end calls with a pinch of the cord, while the built-in microphone allows you to call hands-free, making them easy to use. 🎵【High Quality Sound】The earbuds use 100% copper core to provide lossless digital sound quality, supporting 48KHz and 24-bit audio output for better sound transmission stability and fidelity, while the ergonomic noise reduction in-ear headphones minimize the noise in the surrounding environment and bring you a better music experience. 🎵【Wired Bluetooth Headset】 As this earphone is a Bluet00th connectivity version. You need to turn on the Bluet00th in your Phone or Pad, then plug the earphone in to connect them. When next time you use the earphone again, it will automatically connect to your device in 2-8 seconds. ATTENTION: This is very important, it is the first step that must done. 🎵【Risk-free Guarantee】With our 12 months quality assurance service and 7*24 online support, we are committed to providing satisfactory service to all our customers, ensuring that any questions or concerns are quickly resolved.', 'first_large_image': 'https://m.media-amazon.com/images/I/31NcKi417vL._AC_.jpg', 'rating_number': 2154, 'price': 8.99, 'average_rating': 4.6}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=47, version=2, score=0.4, payload={'text': 'Tiksounds Wireless Earbuds, Bluetooth 5.3 Headphones, Bluetooth Earbuds with LED Display, 60 Hrs of Playtime, IPX7 Waterproof, Stereo Sound, Over Ear Earphones with Mic for Sports Running Workout Gym LED Digital Power Display: Wireless earbuds with LED display to clearly show the battery level of the charging case and earbuds. 60 Hours of Playback: Up to 10 hours of listening time on a single earbuds, over 60 hours with charging case. Bluetoth 5.3 and Stereo Sound Quality: Bluetooth earbuds with Bluetooth 5.3 chip technology and 10mm drivers let you experience crystal clear HD stereo sound and powerful bass. Designed for Sports: The adjustable, firm-fitting ear hooks keep the earphones stable. Keeps you comfortable during a hard workout or run. IPX7 Waterproof: IPX7 rated waterproof earbuds with nano-coating technology to prevent sweat and rain from damaging the components of the wireless earbuds.', 'first_large_image': 'https://m.media-amazon.com/images/I/41ohzPgqMnL._AC_.jpg', 'rating_number': 576, 'price': None, 'average_rating': 4.4}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=39, version=2, score=0.16666667, payload={'text': '[Apple MFi Certified] Lightning to 3.5 mm Headphone Jack Adapter for iPhone, 2 in 1 Lightning to 3.5mm AUX Audio Charger Splitter Compatible with iPhone 13 12 11 XS XR X 8 7 Audio Earphone Adaptor ✔Apple MFi Certified - The iPhone Headphones adapter has passed Apple MFi certification, which means this iPhone aux adapter guaranteed high quality and compatibility, No Error Message Pop-up. Perfect match all 3.5mm Headphone/Earphone. ✔Widely Compatible - This lightning to 3.5mm headphones jack adapter is compatible with iPhone 13/13 Mini/13 Pro/13 Pro Max/12/12 Mini/12 Pro/12 Pro Max/SE 2020/11/11 Pro/XS/XR/X/8/8 Plus/7/7 Plus, iPad, iPod. Support iOS 15 and before, you will be able to keep playing music using your original 3.5mm headphones/aux cable in the car. ✔Multi Function - The 2 in 1 Lightning to 3.5mm Headphone Audio & Charger adapter cable supports listen to music and charge your phone at the same time. Support Charging, Headset Control, Data Transfer, Microphone and Remote. ✔Plug and Play - No extra software, 2 in 1 iPhone Charger and headphones adapter supports up to 24bit 48kHz lossless output, ensuring sound transmission stability and fidelity.Allows you to enjoy perfect music while charging, without worrying about running out of battery.Particularly Designed for iPhone Lovers. ✔Quality Service - You will get 1 * iPhone Headphone Adapter, we also provide a 12-Month Worry-Free Warranty and Lifetime Technical Support. Any issues with this iPhone dongle adapter, contact us for fast support.', 'first_large_image': 'https://m.media-amazon.com/images/I/41TyJiMnk-L._AC_.jpg', 'rating_number': 296, 'price': 8.99, 'average_rating': 3.0}, vector=None, shard_key=None, order_value=None)]

# %%
import instructor
from pydantic import BaseModel
from openai import OpenAI

# %%
class RAGGenerationResponse(BaseModel):
    answer: str

client = instructor.from_openai(OpenAI())

prompt = """
You are a helpful assistant.
Return an answer to the question.
Question: What is your name?
"""
response, raw_response = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=RAGGenerationResponse,
    messages=[{"role": "user", "content": prompt}],
    temperature=0.5
)
